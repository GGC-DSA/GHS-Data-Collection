# %% [markdown]
# Project Title: Second Iteration
# # Data Collection for Green & Healthy Schools (GHS)
#
# ##### Project Description: The "Data Collection for Green & Healthy Schools (GHS)" project aims to revolutionize environmental data management within Gwinnett County Public Schools by developing a sophisticated online system. This system will comprise an intuitive data submission form and a dynamic dashboard, empowering teachers, principals, and program managers to comprehensively assess environmental practices and initiatives across classrooms. The project's primary objectives include facilitating easy data collection, enabling visualization of environmental impact data, and fostering informed decision-making to promote sustainability. Key features encompass secure user authentication, user-friendly data submission, searchable project database, and robust data security measures. By adhering to stringent requirements and leveraging modern technologies, the project aspires to enhance environmental education and instill a culture of sustainability within the educational ecosystem of Gwinnett County.

# %% [markdown]
# ### Nhat Minh Vu Section, Data Set 1
#
# Our clients provided us with 2 datasets, so there was no need for us to search for one. However, the first dataset was disorganized, containing a mix of numeric and character data. For instance, in the 'Number of Students Enrolled in School' column, entries included variations such as 'approximate 900', '~900', '900-950', and 'None'. To clean this up, I manually removed the non-numeric characters, leaving only the numbers. For instances where there was a range, like '900-950', I replaced it with the average, in this case, 925. Additionally, other columns contained values like 'NA', 'N/A', 'None', and 'No'. I removed these values, leaving the fields empty.

# %% [markdown]
# #  My hypotheis:"The number of students enrolled in school is the most important factor influencing the various aspects of environmental education activities."

# %%
import pandas as pd
import numpy as np

# Read the CSV file into a DataFrame with a different encoding
df = pd.read_csv("UPDATE TABLE GGC_2023 Green and Healthy Schools Profile_Data Capture.csv",encoding='ISO-8859-1')

# Display the DataFrame
print(df.head())
# Out:
#                     Timestamp                        Userme  \
# 0   2023/04/20 8:38:18 AM EST    johan_disney@g.gcpsk12.org
# 1   2023/04/23 6:42:59 PM EST   melissa_barth@g.gcpsk12.org
# 2   2023/04/25 7:56:05 AM EST  karyn_pumphrey@g.gcpsk12.org
# 3  2023/04/27 12:16:26 PM EST     tammi_adams@g.gcpsk12.org
# 4   2023/04/28 9:16:22 AM EST    roshan_finch@g.gcpsk12.org
#
#                      School me  \
# 0                    McKendree
# 1           Harbins Elementary
# 2            Corley Elementary
# 3  White Oak Elementary School
# 4    Simpson Elementary School
#
#              me(s) of GHS Teacher Representative(s)   \
# 0  Johan Disney, Julie Wilkerson, Ilya Morales, A...
# 1                                     Melissa Barth
# 2                                 Dr. Karyn Pumphrey
# 3                                        Tammi Adams
# 4              Roshan Finch/Sheri Terry/Kathryn Arld
#
#   Number of Students Enrolled in School  \
# 0                                  1200
# 1                                  1463
# 2                                  1200
# 3                                   714
# 4                                   970
#
#    Number of Teachers and Support Staff within School  \
# 0                                               90.0
# 1                                              162.0
# 2                                               83.0
# 3                                               91.0
# 4                                              150.0
#
#   What were three Environmental Education goals for this current school year? 1) Number them as you list them and 2) describe if you were able to reach the goals set at the beginning of the year.  \
# 0  1. Food waste, we were able to complete a food...
# 1  1. Reduce the amount of trash outside- differe...
# 2  1)  Reduce food waste.  We met the goal by exp...
# 3  1.  To teach students the importance of pollit...
# 4  Continue school wide recycling; bring awarenes...
#
#   Describe a student project that addressed real-world environmental issues. Include 1) who did the project (grade level, class, club, etc) 2) project description and 3) outcome/impact.   \
# 0  Garden , k-2 speech kids, involving the studen...
# 1  Students K-5 were part of the Great Georgia Po...
# 2  1)  Sage:  a fifth grader, in science fair clu...
# 3  Kindergarten: Improving the Soil turally with ...
# 4  1. A group of 3rd grade boys 2. Created a "tra...
#
#    If you described a PBL in the question above, please tell us how many students were involved.  \
# 0                                               50.0
# 1                                              150.0
# 2                                               50.0
# 3                                              750.0
# 4                                              450.0
#
#   Did your school partner with community agencies, organizations, businesses, etc. to enhance environmental learning?   \
# 0       We did t partner with any community agencies
# 1                  Speaker;Adopt a Hive, Adopt a Cow
# 2            Speaker;Virtual or In-person field trip
# 3  Speaker;Virtual or In-person field trip;Adopt-...
# 4       We did t partner with any community agencies
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Does your school have indoor growing systems? Check all that apply below.  \
# 0                                       Tower Garden
# 1                                       Tower Garden
# 2        We do t have an indoor system at our school
# 3  Tower Garden;Our school has an indoor garden c...
# 4        We do t have an indoor system at our school
#
#    If you checked any boxes above, please 1) describe your system 2) whether food is doted to students or the community and 3) approximately how many pounds were doted this year. *If your school has  such system , type .  \
# 0  Just started, a few pounds  have grown, doted ...
# 1  We have one Tower Garden per grade level and o...
# 2                                                NaN
# 3  The first graders use the tower gardens for th...
# 4                                                NaN
#
#   If you answered the question above, please tell us how many students utilize the area(s)..1  \
# 0                                               50.0
# 1                                              200.0
# 2                                                NaN
# 3                                              200.0
# 4                                                NaN
#
#   Has your school received grants/funding this year to begin or expand environmental projects?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#    If yes, list the 1) who sponsored the grant 2) amount received and 3) how the funding was utilized. *Type  if t applicable.  \
# 0                                 Compost connectors
# 1  1. Peanut and Beyond Grant- $2000- funding was...
# 2  The gardening club received dotions for initia...
# 3  GCMGA 2023 Grant $435 (Shelf with Grow lights ...
# 4                                                NaN
#
#   Does your school contract with a local company for recycling? Check all that apply.  \
# 0                                   textile/clothing
# 1             Our school does t recycle at this time
# 2                                    paper;cardboard
# 3  paper;cardboard;textile/clothing;plastic (bott...
# 4  paper;cardboard;textile/clothing;plastic (bott...
#
#   If yes, please list 1) the company and 2) the monthly cost of the service for all items recycled. *Type  if t applicable.  \
# 0                                    Good will  cost
# 1                                                NaN
# 2  We do t have a contract with a local company. ...
# 3  Paper and Cardboard: Solid Waste Recycling Div...
# 4                1. Waste Magement 2. $600 per year
#
#   Please check off all water-related content topics that were covered in classes or student clubs.  {**Water related AKS is embedded in many grade levels so this question must be answered.}   \
# 0  water pollution;water conservation;land uses/e...
# 1  water pollution;water conservation;land uses/e...
# 2  water pollution;water conservation;land uses/e...
# 3  water pollution;water conservation;land uses/e...
# 4  water pollution;water conservation;land uses/e...
#
#   Please number your answers as follows. 1) list each activity, 2) the date(s) the activity was held (approximate if necessary), 3) the number of students that participated in the activity, and 4) the total amount of time the students were engaged in the activity. 5) Total hours of Water-related learning\n(ex: 1) DWR visit 2) October 15, 2022 for 3) 213 students (entire 3rd grade) 4) Program lasted 3 hours) 5) 639 hrs.\n{**Water related AKS is embedded in many grade levels so this question must be answered.}   \
# 0  Water pollution, 3rd grade 125, 3 hours, Water...
# 1  1. DWR visit 2. January 2023 3. 265 students (...
# 2  1)  Water pollution and frog conservation 2) O...
# 3  4th Grade:  Water on Wheels Program, Unit on W...
# 4  1. Real World Issues covered during Computer S...
#
#    *Please title your folder with your school me and insert link or attach pictures/videos here to show off your awesome achievements. :-)
# 0  https://drive.google.com/u/1/open?usp=forms_we...
# 1  https://drive.google.com/u/1/open?usp=forms_we...
# 2                                                NaN
# 3  https://drive.google.com/u/1/open?usp=forms_we...
# 4  https://drive.google.com/u/1/open?usp=forms_we...
#
# [5 rows x 30 columns]

# %%
# Display summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
print(df.describe())
# Out:
# Summary Statistics for Numerical Columns:
#        Number of Teachers and Support Staff within School  \
# count                                          75.000000
# mean                                          158.005333
# std                                           241.131201
# min                                             2.000000
# 25%                                            95.000000
# 50%                                           125.000000
# 75%                                           157.000000
# max                                          2168.000000
#
#        If you described a PBL in the question above, please tell us how many students were involved.  \
# count                                          66.000000
# mean                                          211.742424
# std                                           232.470829
# min                                            50.000000
# 25%                                            50.000000
# 50%                                           150.000000
# 75%                                           200.000000
# max                                           925.000000
#
#        If you answered the question above, please tell us how many students were involved with the community partnership.   \
# count                                          59.000000
# mean                                          336.440678
# std                                           336.927101
# min                                            50.000000
# 25%                                            50.000000
# 50%                                           200.000000
# 75%                                           450.000000
# max                                           950.000000
#
#        If you answered the question above, please tell us how many students participated.  \
# count                                          44.000000
# mean                                          489.772727
# std                                           348.014225
# min                                            50.000000
# 25%                                           200.000000
# 50%                                           450.000000
# 75%                                           750.000000
# max                                           950.000000
#
#        If you answered the question above, please tell us how many students utilize the area(s).  \
# count                                          64.000000
# mean                                          416.406250
# std                                           342.615371
# min                                            50.000000
# 25%                                            50.000000
# 50%                                           450.000000
# 75%                                           750.000000
# max                                           950.000000
#
#        If you answered the question above, please tell us how many students utilize the area(s)..1
# count                                          46.000000
# mean                                          320.652174
# std                                           344.895489
# min                                            50.000000
# 25%                                            50.000000
# 50%                                           200.000000
# 75%                                           450.000000
# max                                           950.000000

# %%
# Handling duplicates, because there are not many row and in the table so I want to keep as many row and column as possible.
df.drop_duplicates(inplace=True)


# Display information after cleaning
print("\nDataFrame after cleaning:")
print(df.head())
# Out:
# DataFrame after cleaning:
#                     Timestamp                        Userme  \
# 0   2023/04/20 8:38:18 AM EST    johan_disney@g.gcpsk12.org
# 1   2023/04/23 6:42:59 PM EST   melissa_barth@g.gcpsk12.org
# 2   2023/04/25 7:56:05 AM EST  karyn_pumphrey@g.gcpsk12.org
# 3  2023/04/27 12:16:26 PM EST     tammi_adams@g.gcpsk12.org
# 4   2023/04/28 9:16:22 AM EST    roshan_finch@g.gcpsk12.org
#
#                      School me  \
# 0                    McKendree
# 1           Harbins Elementary
# 2            Corley Elementary
# 3  White Oak Elementary School
# 4    Simpson Elementary School
#
#              me(s) of GHS Teacher Representative(s)   \
# 0  Johan Disney, Julie Wilkerson, Ilya Morales, A...
# 1                                     Melissa Barth
# 2                                 Dr. Karyn Pumphrey
# 3                                        Tammi Adams
# 4              Roshan Finch/Sheri Terry/Kathryn Arld
#
#   Number of Students Enrolled in School  \
# 0                                  1200
# 1                                  1463
# 2                                  1200
# 3                                   714
# 4                                   970
#
#    Number of Teachers and Support Staff within School  \
# 0                                               90.0
# 1                                              162.0
# 2                                               83.0
# 3                                               91.0
# 4                                              150.0
#
#   What were three Environmental Education goals for this current school year? 1) Number them as you list them and 2) describe if you were able to reach the goals set at the beginning of the year.  \
# 0  1. Food waste, we were able to complete a food...
# 1  1. Reduce the amount of trash outside- differe...
# 2  1)  Reduce food waste.  We met the goal by exp...
# 3  1.  To teach students the importance of pollit...
# 4  Continue school wide recycling; bring awarenes...
#
#   Describe a student project that addressed real-world environmental issues. Include 1) who did the project (grade level, class, club, etc) 2) project description and 3) outcome/impact.   \
# 0  Garden , k-2 speech kids, involving the studen...
# 1  Students K-5 were part of the Great Georgia Po...
# 2  1)  Sage:  a fifth grader, in science fair clu...
# 3  Kindergarten: Improving the Soil turally with ...
# 4  1. A group of 3rd grade boys 2. Created a "tra...
#
#    If you described a PBL in the question above, please tell us how many students were involved.  \
# 0                                               50.0
# 1                                              150.0
# 2                                               50.0
# 3                                              750.0
# 4                                              450.0
#
#   Did your school partner with community agencies, organizations, businesses, etc. to enhance environmental learning?   \
# 0       We did t partner with any community agencies
# 1                  Speaker;Adopt a Hive, Adopt a Cow
# 2            Speaker;Virtual or In-person field trip
# 3  Speaker;Virtual or In-person field trip;Adopt-...
# 4       We did t partner with any community agencies
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Does your school have indoor growing systems? Check all that apply below.  \
# 0                                       Tower Garden
# 1                                       Tower Garden
# 2        We do t have an indoor system at our school
# 3  Tower Garden;Our school has an indoor garden c...
# 4        We do t have an indoor system at our school
#
#    If you checked any boxes above, please 1) describe your system 2) whether food is doted to students or the community and 3) approximately how many pounds were doted this year. *If your school has  such system , type .  \
# 0  Just started, a few pounds  have grown, doted ...
# 1  We have one Tower Garden per grade level and o...
# 2                                                NaN
# 3  The first graders use the tower gardens for th...
# 4                                                NaN
#
#   If you answered the question above, please tell us how many students utilize the area(s)..1  \
# 0                                               50.0
# 1                                              200.0
# 2                                                NaN
# 3                                              200.0
# 4                                                NaN
#
#   Has your school received grants/funding this year to begin or expand environmental projects?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#    If yes, list the 1) who sponsored the grant 2) amount received and 3) how the funding was utilized. *Type  if t applicable.  \
# 0                                 Compost connectors
# 1  1. Peanut and Beyond Grant- $2000- funding was...
# 2  The gardening club received dotions for initia...
# 3  GCMGA 2023 Grant $435 (Shelf with Grow lights ...
# 4                                                NaN
#
#   Does your school contract with a local company for recycling? Check all that apply.  \
# 0                                   textile/clothing
# 1             Our school does t recycle at this time
# 2                                    paper;cardboard
# 3  paper;cardboard;textile/clothing;plastic (bott...
# 4  paper;cardboard;textile/clothing;plastic (bott...
#
#   If yes, please list 1) the company and 2) the monthly cost of the service for all items recycled. *Type  if t applicable.  \
# 0                                    Good will  cost
# 1                                                NaN
# 2  We do t have a contract with a local company. ...
# 3  Paper and Cardboard: Solid Waste Recycling Div...
# 4                1. Waste Magement 2. $600 per year
#
#   Please check off all water-related content topics that were covered in classes or student clubs.  {**Water related AKS is embedded in many grade levels so this question must be answered.}   \
# 0  water pollution;water conservation;land uses/e...
# 1  water pollution;water conservation;land uses/e...
# 2  water pollution;water conservation;land uses/e...
# 3  water pollution;water conservation;land uses/e...
# 4  water pollution;water conservation;land uses/e...
#
#   Please number your answers as follows. 1) list each activity, 2) the date(s) the activity was held (approximate if necessary), 3) the number of students that participated in the activity, and 4) the total amount of time the students were engaged in the activity. 5) Total hours of Water-related learning\n(ex: 1) DWR visit 2) October 15, 2022 for 3) 213 students (entire 3rd grade) 4) Program lasted 3 hours) 5) 639 hrs.\n{**Water related AKS is embedded in many grade levels so this question must be answered.}   \
# 0  Water pollution, 3rd grade 125, 3 hours, Water...
# 1  1. DWR visit 2. January 2023 3. 265 students (...
# 2  1)  Water pollution and frog conservation 2) O...
# 3  4th Grade:  Water on Wheels Program, Unit on W...
# 4  1. Real World Issues covered during Computer S...
#
#    *Please title your folder with your school me and insert link or attach pictures/videos here to show off your awesome achievements. :-)
# 0  https://drive.google.com/u/1/open?usp=forms_we...
# 1  https://drive.google.com/u/1/open?usp=forms_we...
# 2                                                NaN
# 3  https://drive.google.com/u/1/open?usp=forms_we...
# 4  https://drive.google.com/u/1/open?usp=forms_we...
#
# [5 rows x 30 columns]

# %%
import matplotlib.pyplot as plt

# Convert 'Number of Students Enrolled in School' column to numeric
df['Number of Students Enrolled in School'] = pd.to_numeric(df['Number of Students Enrolled in School'], errors='coerce')

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(df['School me'], df['Number of Students Enrolled in School'])
plt.title('Number of Students Enrolled in Each School')
plt.xlabel('School Name')
plt.ylabel('Number of Students Enrolled')
plt.xticks(rotation=45, ha='right')

# Scaling up the y-axis
plt.ylim(bottom=0, top=df['Number of Students Enrolled in School'].max() * 1.1)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is already loaded and named df
# If not, load your DataFrame using pd.read_csv() first

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(df['School me'], df['Number of Teachers and Support Staff within School'])
plt.title('Number of Teachers and Support Staff within Each School')
plt.xlabel('School Name')
plt.ylabel('Number of Teachers and Support Staff')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Convert 'Timestamp' column to datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Plotting
plt.figure(figsize=(12, 6))
df['Timestamp'].dt.date.value_counts().sort_index().plot(kind='bar')
plt.title('Frequency of Timestamps')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
plt.figure(figsize=(10, 6))
df['If you described a PBL in the question above, please tell us how many students were involved.'].value_counts().plot(kind='bar')
plt.title('Frequency of Students Involved in PBL')
plt.xlabel('Number of Students Involved')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation coefficient
correlation_coefficient = df['Number of Students Enrolled in School'].corr(df['Number of Teachers and Support Staff within School'])

# Print the correlation coefficient
print("Correlation Coefficient:", correlation_coefficient)

# Verify hypothesis
if correlation_coefficient > 0:
    print("The correlation coefficient is positive, indicating a positive linear relationship.")
    print("Therefore, the school that has more students enrolled tends to have more teachers and support staff participating in the project.")
elif correlation_coefficient < 0:
    print("The correlation coefficient is negative, indicating a negative linear relationship.")
    print("Therefore, the school that has more students enrolled tends to have fewer teachers and support staff participating in the project.")
else:
    print("There is no linear relationship between the number of students enrolled and the number of teachers and support staff participating in the project.")
# Out:
# Correlation Coefficient: 0.3191566119663813
# The correlation coefficient is positive, indicating a positive linear relationship.
# Therefore, the school that has more students enrolled tends to have more teachers and support staff participating in the project.

# %%
# Sort DataFrame by 'Number of Students Enrolled in School'
df_sorted = df.sort_values(by='Number of Students Enrolled in School')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df_sorted['Number of Students Enrolled in School'], df_sorted['Number of Teachers and Support Staff within School'], marker='o', linestyle='-')
plt.title('Relationship between Number of Students and Teachers/Staff')
plt.xlabel('Number of Students Enrolled in School')
plt.ylabel('Number of Teachers and Support Staff within School')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert columns with numeric data to numeric types
numeric_columns = ['Number of Teachers and Support Staff within School',
                   'If you answered the question above, please tell us how many students were involved with the community partnership. ',
                   'If you answered the question above, please tell us how many students participated.',
                   'If you answered the question above, please tell us how many students utilize the area(s).',
                   'If you answered the question above, please tell us how many students utilize the area(s)..1']

# Iterate through numeric columns and convert them to numeric types
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check the data types again to ensure conversion
print(df.dtypes)
# Out:
# Timestamp                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           datetime64[ns]
# Userme                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      object
# School me                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   object
# me(s) of GHS Teacher Representative(s)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      object
# Number of Students Enrolled in School                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      float64
# Number of Teachers and Support Staff within School                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         float64
# What were three Environmental Education goals for this current school year? 1) Number them as you list them and 2) describe if you were able to reach the goals set at the beginning of the year.                                                                                                                                                                                                                                                                                                                                           object
# Describe a student project that addressed real-world environmental issues. Include 1) who did the project (grade level, class, club, etc) 2) project description and 3) outcome/impact.                                                                                                                                                                                                                                                                                                                                                     object
# If you described a PBL in the question above, please tell us how many students were involved.                                                                                                                                                                                                                                                                                                                                                                                                                                              float64
# Did your school partner with community agencies, organizations, businesses, etc. to enhance environmental learning?                                                                                                                                                                                                                                                                                                                                                                                                                         object
# Please list any community partners that you worked with this year and describe their involvement.                                                                                                                                                                                                                                                                                                                                                                                                                                           object
# If you answered the question above, please tell us how many students were involved with the community partnership.                                                                                                                                                                                                                                                                                                                                                                                                                         float64
# If your school participated in activities to reduce cafeteria food waste, please describe in detail.                                                                                                                                                                                                                                                                                                                                                                                                                                        object
# What strategies were identified and initiated to reduce cafeteria food waste?                                                                                                                                                                                                                                                                                                                                                                                                                                                               object
# If you answered the question above, please tell us how many students participated.                                                                                                                                                                                                                                                                                                                                                                                                                                                         float64
# Does your school actively compost waste?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    object
# If you answered yes above, please describe 1) what items are collected for composting and 2) describe the collection process at your school. Also include 3) what is done with the compost and 4) approximate pounds of food waste that is collected. *If  composting was done, type .                                                                                                                                                                                                                                                      object
# Does your school have outdoor green spaces or gardens utilized for instruction?  Examples include: edible gardens, pollitor gardens, etc.                                                                                                                                                                                                                                                                                                                                                                                                   object
# If yes to the question above, 1) describe the learning area(s) and 2) include if food is doted and 3) how it is distributed.  *If your school has  such system, type .                                                                                                                                                                                                                                                                                                                                                                      object
# If you answered the question above, please tell us how many students utilize the area(s).                                                                                                                                                                                                                                                                                                                                                                                                                                                  float64
# Does your school have indoor growing systems? Check all that apply below.                                                                                                                                                                                                                                                                                                                                                                                                                                                                   object
# If you checked any boxes above, please 1) describe your system 2) whether food is doted to students or the community and 3) approximately how many pounds were doted this year. *If your school has  such system , type .                                                                                                                                                                                                                                                                                                                   object
# If you answered the question above, please tell us how many students utilize the area(s)..1                                                                                                                                                                                                                                                                                                                                                                                                                                                float64
# Has your school received grants/funding this year to begin or expand environmental projects?                                                                                                                                                                                                                                                                                                                                                                                                                                                object
# If yes, list the 1) who sponsored the grant 2) amount received and 3) how the funding was utilized. *Type  if t applicable.                                                                                                                                                                                                                                                                                                                                                                                                                 object
# Does your school contract with a local company for recycling? Check all that apply.                                                                                                                                                                                                                                                                                                                                                                                                                                                         object
# If yes, please list 1) the company and 2) the monthly cost of the service for all items recycled. *Type  if t applicable.                                                                                                                                                                                                                                                                                                                                                                                                                   object
# Please check off all water-related content topics that were covered in classes or student clubs.  {**Water related AKS is embedded in many grade levels so this question must be answered.}                                                                                                                                                                                                                                                                                                                                                 object
# Please number your answers as follows. 1) list each activity, 2) the date(s) the activity was held (approximate if necessary), 3) the number of students that participated in the activity, and 4) the total amount of time the students were engaged in the activity. 5) Total hours of Water-related learning\n(ex: 1) DWR visit 2) October 15, 2022 for 3) 213 students (entire 3rd grade) 4) Program lasted 3 hours) 5) 639 hrs.\n{**Water related AKS is embedded in many grade levels so this question must be answered.}             object
# *Please title your folder with your school me and insert link or attach pictures/videos here to show off your awesome achievements. :-)                                                                                                                                                                                                                                                                                                                                                                                                     object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# Load the dataset
# Assuming your DataFrame is named df

# Step 1: Explore the distribution of the number of students enrolled in school
plt.figure(figsize=(8, 6))
sns.histplot(df['Number of Students Enrolled in School'], bins=20, kde=True)
plt.title('Distribution of Number of Students Enrolled in School')
plt.xlabel('Number of Students')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np

# Remove non-numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=np.number)

# Remove rows with missing or infinite values
numeric_df = numeric_df.dropna()
numeric_df = numeric_df.replace([np.inf, -np.inf], np.nan).dropna()

# Select the dependent variable
y = numeric_df['Number of Students Enrolled in School']

# Select the independent variables
X = numeric_df.drop(columns=['Number of Students Enrolled in School'])


# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the OLS model OLS stands for Ordinary Least Squares, which is a method used in linear regression analysis to estimate the parameters of a linear regression model.
# In an OLS model, the goal is to minimize the sum of the squared differences between the observed values of the dependent variable and the values predicted by the linear regression equation.
model = sm.OLS(y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                                       OLS Regression Results
# =================================================================================================
# Dep. Variable:     Number of Students Enrolled in School   R-squared:                       0.315
# Model:                                               OLS   Adj. R-squared:                  0.021
# Method:                                    Least Squares   F-statistic:                     1.072
# Date:                                   Thu, 11 Apr 2024   Prob (F-statistic):              0.424
# Time:                                           16:49:12   Log-Likelihood:                -162.46
# No. Observations:                                     21   AIC:                             338.9
# Df Residuals:                                         14   BIC:                             346.2
# Df Model:                                              6
# Covariance Type:                               nonrobust
# =======================================================================================================================================================================================
#                                                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                                1060.3342    336.751      3.149      0.007     338.075    1782.593
# Number of Teachers and Support Staff within School                                                                      0.8785      0.390      2.253      0.041       0.042       1.715
# If you described a PBL in the question above, please tell us how many students were involved.                          -0.3865      0.734     -0.527      0.607      -1.960       1.187
# If you answered the question above, please tell us how many students were involved with the community partnership.      0.0598      0.652      0.092      0.928      -1.339       1.459
# If you answered the question above, please tell us how many students participated.                                     -0.4593      0.542     -0.847      0.411      -1.622       0.704
# If you answered the question above, please tell us how many students utilize the area(s).                               0.5616      0.453      1.240      0.235      -0.410       1.533
# If you answered the question above, please tell us how many students utilize the area(s)..1                             0.0281      0.520      0.054      0.958      -1.087       1.143
# ==============================================================================
# Omnibus:                       25.739   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.102
# Skew:                           2.123   Prob(JB):                     2.65e-10
# Kurtosis:                       8.689   Cond. No.                     2.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## My hypotheis:"The number of students enrolled in school is the most important factor influencing the various aspects of environmental education activities."
#
#  Reject Hypothesis. The regression results do not directly address this hypothesis because they focus on the relationship between the number of students enrolled in school and other variables, rather than directly assessing the importance of the number of students enrolled.
#
# 1. The coefficients for the number of students enrolled in school and other ariables are not statistically significant (except for the constant term).
#
# The p-values for the coefficients associated with the number of students enrolled in school and other variables are not statistically significant, indicating that these variables may not have a significant effect on the number of students enrolled in school.
#
# This can be observed from the p-values associated with each coefficient in the regression summary table. If the p-value is greater than 0.05, then the corresponding variable is not considered statistically significant in predicting the dependent variable.
#
# This can be from p-values (0.007) for each coefficient in the regression summary table. If the p-value is greater than a chosen significance level (commonly 0.05), then the coefficient is not considered statistically significant. In this case, it is not significant.
#
# 2. The overall explanatory power of the model (R-squared) is low (0.315) normaly it range from 0-1, suggesting that the variables included in the model may not effectively explain the variation in the number of students enrolled in school.
#
# The R-squared value measures the proportion of the variance in the dependent variable (number of students enrolled in school) that is explained by the independent variables in the model. A low R-squared value indicates that the model does not explain much of the variability in the dependent variable.

# %%
df.columns
# Out:
# Index(['Timestamp', 'Userme', 'School me',
#        'me(s) of GHS Teacher Representative(s) ',
#        'Number of Students Enrolled in School',
#        'Number of Teachers and Support Staff within School',
#        'What were three Environmental Education goals for this current school year? 1) Number them as you list them and 2) describe if you were able to reach the goals set at the beginning of the year.',
#        'Describe a student project that addressed real-world environmental issues. Include 1) who did the project (grade level, class, club, etc) 2) project description and 3) outcome/impact. ',
#        'If you described a PBL in the question above, please tell us how many students were involved.',
#        'Did your school partner with community agencies, organizations, businesses, etc. to enhance environmental learning? ',
#        'Please list any community partners that you worked with this year and describe their involvement.',
#        'If you answered the question above, please tell us how many students were involved with the community partnership. ',
#        'If your school participated in activities to reduce cafeteria food waste, please describe in detail.',
#        'What strategies were identified and initiated to reduce cafeteria food waste?',
#        'If you answered the question above, please tell us how many students participated.',
#        'Does your school actively compost waste?',
#        'If you answered yes above, please describe 1) what items are collected for composting and 2) describe the collection process at your school. Also include 3) what is done with the compost and 4) approximate pounds of food waste that is collected. *If  composting was done, type .',
#        'Does your school have outdoor green spaces or gardens utilized for instruction?  Examples include: edible gardens, pollitor gardens, etc.',
#        'If yes to the question above, 1) describe the learning area(s) and 2) include if food is doted and 3) how it is distributed.  *If your school has  such system, type .',
#        'If you answered the question above, please tell us how many students utilize the area(s).',
#        'Does your school have indoor growing systems? Check all that apply below.',
#        'If you checked any boxes above, please 1) describe your system 2) whether food is doted to students or the community and 3) approximately how many pounds were doted this year. *If your school has  such system , type .',
#        'If you answered the question above, please tell us how many students utilize the area(s)..1',
#        'Has your school received grants/funding this year to begin or expand environmental projects?',
#        'If yes, list the 1) who sponsored the grant 2) amount received and 3) how the funding was utilized. *Type  if t applicable.',
#        'Does your school contract with a local company for recycling? Check all that apply.',
#        'If yes, please list 1) the company and 2) the monthly cost of the service for all items recycled. *Type  if t applicable.',
#        'Please check off all water-related content topics that were covered in classes or student clubs.  {**Water related AKS is embedded in many grade levels so this question must be answered.} ',
#        'Please number your answers as follows. 1) list each activity, 2) the date(s) the activity was held (approximate if necessary), 3) the number of students that participated in the activity, and 4) the total amount of time the students were engaged in the activity. 5) Total hours of Water-related learning\n(ex: 1) DWR visit 2) October 15, 2022 for 3) 213 students (entire 3rd grade) 4) Program lasted 3 hours) 5) 639 hrs.\n{**Water related AKS is embedded in many grade levels so this question must be answered.} ',
#        '*Please title your folder with your school me and insert link or attach pictures/videos here to show off your awesome achievements. :-) '],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming df contains your DataFrame with the provided numeric columns

# Select numeric columns
numeric_df = df.select_dtypes(include=np.number)

# Drop rows with missing values
numeric_df.dropna(inplace=True)

# Standardize the data
scaler = StandardScaler()
numeric_df_scaled = scaler.fit_transform(numeric_df)

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(numeric_df_scaled)

# Plot the data before PCA
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Before PCA')
for column in numeric_df.columns:
    plt.scatter(range(len(numeric_df)), numeric_df[column], label=column)
plt.xlabel('Data Point Index')
plt.ylabel('Value')
plt.legend()
plt.ylim(bottom=0)  # Adjust y-axis limit



plt.tight_layout()
plt.show()

# %%
# Plot the data after PCA
plt.subplot(1, 2, 2)
plt.title('After PCA')
plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.tight_layout()
plt.show()

# %%
# Add 'Number of Students Enrolled in School' to numeric columns list
numeric_columns = ['Number of Students Enrolled in School',
                   'Number of Teachers and Support Staff within School',
                   'If you answered the question above, please tell us how many students were involved with the community partnership. ',
                   'If you answered the question above, please tell us how many students participated.',
                   'If you answered the question above, please tell us how many students utilize the area(s).',
                   'If you answered the question above, please tell us how many students utilize the area(s)..1']

# Convert columns with numeric data to numeric types
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# Convert columns with numeric data to numeric types
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
# Plotting scatter plot for each numeric column on the same graph
plt.figure(figsize=(12, 8))
for i, column in enumerate(numeric_columns):
    plt.scatter(df.index, df[column], label=column, alpha=0.7)

plt.title('Scatter Plot of Numeric Columns')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting scatter plot for each numeric column on the same graph
plt.figure(figsize=(12, 8))
for column in numeric_columns:
    sns.regplot(data=df, x=df.index, y=column, label=column)

plt.title('Scatter Plot of Numeric Columns with Regression Lines')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Convert columns with numeric data to numeric types
numeric_columns = ['Number of Students Enrolled in School',
                   'Number of Teachers and Support Staff within School',
                   'If you answered the question above, please tell us how many students were involved with the community partnership. ',
                   'If you answered the question above, please tell us how many students participated.',
                   'If you answered the question above, please tell us how many students utilize the area(s).',
                   'If you answered the question above, please tell us how many students utilize the area(s)..1']

df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Define colors for each column
colors = ['red', 'black', 'blue', 'pink', 'purple', 'green']

# Plotting scatter plot for each numeric column on the same graph
plt.figure(figsize=(12, 8))
for i, column in enumerate(numeric_columns):
    if column in ["Number of Students Enrolled in School", "Number of Teachers and Support Staff within School"]:
        sns.regplot(data=df, x=df.index, y=column, label=column, scatter_kws={'color': colors[i]}, line_kws={'color': colors[i]})
    else:
        plt.scatter(df.index, df[column], label=column, alpha=0.7, color=colors[i])

plt.title('Scatter Plot of Numeric Columns with Regression Lines')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Shantel Parrish​

# %% [markdown]
# Hypothesis: There is a correlation between the presence of
# green spaces utilized for instruction and participating in composting waste

# %%
import pandas as pd

df = pd.read_csv("UPDATE TABLE GGC_2023 Green and Healthy Schools Profile_Data Capture - UPDATE TABLE GGC_2023 Green and Healthy Schools Profile_Data Capture.csv", encoding='ISO-8859-1')

# %%
from scipy.stats import chi2_contingency

contingency_df = df[["Does your school have outdoor green spaces or gardens utilized for instruction?  Examples include: edible gardens, pollitor gardens, etc.", "Does your school actively compost waste?"]]

contingency_table = pd.crosstab(df["Does your school have outdoor green spaces or gardens utilized for instruction?  Examples include: edible gardens, pollitor gardens, etc."], df["Does your school actively compost waste?"])

chi2, p, dof, expected = chi2_contingency(contingency_table)

print("Contingency Table:")
print(contingency_table)
print("\n")

print("Chi-square test results:")
print(f"Chi-square: {chi2}")
print(f"P-value: {p}")
# Out:
# Contingency Table:
# Does your school actively compost waste?            No  Yes
# Does your school have outdoor green spaces or g...
# No                                                  10    1
# Yes                                                 46   18
#
#
# Chi-square test results:
# Chi-square: 0.932398579011449
# P-value: 0.33424043047323554

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(contingency_table, annot=True, fmt="d", cmap="Blues")
plt.title("Correlation between Outdoor Spaces and Composting Waste")
plt.xlabel("Composting Waste")
plt.ylabel("Outdoor Spaces")
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

categories = ["No Composting, No Green Space", "Composting, No Green Space", "No Composting, Green Space", "Composting, Green Space"]

counts = [contingency_table.loc["No", "No"], contingency_table.loc["Yes", "No"], contingency_table.loc["No", "Yes"], contingency_table.loc["Yes", "Yes"]]

sns.barplot(x="Categories", y="Counts", data=pd.DataFrame({"Categories": categories, "Counts": counts}), palette=['#8cbf3f','#8cbf3f','#8cbf3f','#8cbf3f'], hue="Categories", dodge=False, legend=False)

plt.title("Composting Waste is Preferred When Green Spaces are Not Available")
plt.xlabel("Outdoor Spaces and Composting Waste")
plt.ylabel("Count")

plt.xticks(size =8)
plt.savefig('association_graph.png')

# %% [markdown]
# A contingency table shows  a clear connection between outdoor spaces and composting practices in schools, with most lacking composting initiatives despite having green areas, except for one school, indicating a potential target for focused intervention and further research.

# %% [markdown]
# Extra: Top Schools with the Most Student Participation

# %%
column_indices = [8,11,14,19,22]

def bin_score(value):
    if value == '1-100':
        return 1
    elif value == '101-300':
        return 2
    elif value == '301-600':
        return 3
    elif value == '601-900':
        return 4
    elif value == '901-950':
        return 5
    else:
        return None

for index in column_indices:
  df.iloc[:,index] = df.iloc[:,index].apply(bin_score)

df['Total_Score'] = df.iloc[:, column_indices].sum(axis=1)

top_schools = df.sort_values(by='Total_Score', ascending=False).head(10)

top_schools.reset_index(drop=True, inplace=True)
top_schools.index += 1


print("Top 10 Schools with the Most Participation:")
print(top_schools[['School me']].to_string(header=False))
# Out:
# Top 10 Schools with the Most Participation:
# 1                     McKendree
# 2         Seckinger High School
# 3         Trickum Middle School
# 4    rth Gwinnett Middle School
# 5                    Parsons ES
# 6                Mir Elementary
# 7                  Gwin Oaks ES
# 8     Grayson Elementary School
# 9   Brookwood Elementary School
# 10            Knight Elementary
